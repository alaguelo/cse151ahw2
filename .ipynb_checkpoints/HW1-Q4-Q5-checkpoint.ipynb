# %% [markdown]
# ### Q4 Data Visualization

# %%
import matplotlib.pyplot as plt
from sklearn import datasets

# %%
# Load data
wine = datasets.load_wine()
X = wine.data
Y = wine.target
print(X.shape, Y.shape)
# Out:
# (178, 13) (178,)

# %%
###### To be filled ######
# Hint: You may use plt.scatter() to draw the plot. You may need to set the 'c' argument
#       in order to have different color for the data points with different classes in Y.or
plt.scatter(X[:, 0], X[:, 1], c=Y, cmap='viridis')
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.title("Q4 Data Visualization Feature 1 & 2")
plt.colorbar(label="Class")
plt.show()

# %% [markdown]
# ### Q5 Data Manipulation

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets
# Load data
wine = datasets.load_wine()
X = wine.data
Y = wine.target
print(X.shape, Y.shape)
# Out:
# (178, 13) (178,)

# %% [markdown]
# 1.  Show the first 2 features of the first 3 data points.

# %%
###### To be filled ######
X[:3, :2]
# Out:
# array([[14.23,  1.71],
#        [13.2 ,  1.78],
#        [13.16,  2.36]])

# %% [markdown]
# 2. Calculate the mean and the variance of the 1st feature (the 1st column) of array $X$.

# %%
###### To be filled ######
# Hint: You may use np.mean() and np.var()
meanFeature1 = np.mean(X[:, 0])
varianceFeature1 = np.var(X[:, 0])
print(meanFeature1)
print(varianceFeature1)
# Out:
# 13.00061797752809
# 0.6553597304633255

# %% [markdown]
# 3. Randomly sample 3 data points (rows) of array $X$ by randomly choosing the row indices. Show the indices and the sampled data points.

# %%
###### To be filled ######
# Hint: You may use np.random.randint().
indices = np.random.randint(0, X.shape[0], 3);
sampled = X[indices]
print(indices)
print(sampled)
# Out:
# [89 73 14]
# [[1.208e+01 1.330e+00 2.300e+00 2.360e+01 7.000e+01 2.200e+00 1.590e+00
#   4.200e-01 1.380e+00 1.740e+00 1.070e+00 3.210e+00 6.250e+02]
#  [1.299e+01 1.670e+00 2.600e+00 3.000e+01 1.390e+02 3.300e+00 2.890e+00
#   2.100e-01 1.960e+00 3.350e+00 1.310e+00 3.500e+00 9.850e+02]
#  [1.438e+01 1.870e+00 2.380e+00 1.200e+01 1.020e+02 3.300e+00 3.640e+00
#   2.900e-01 2.960e+00 7.500e+00 1.200e+00 3.000e+00 1.547e+03]]

# %% [markdown]
# 4. Add one more feature (one more column) to the array $X$ after the last feature.  The values of the added feature for all data points are constant 1.  Show the first data point (first row) of the new array

# %%
###### To be filled ######
# Hint: You may use np.hstack() and np.ones()
onesCol = np.ones((X.shape[0], 1))
newArr = np.hstack((X, onesCol))
print(X[0])
print(newArr[0])
# Out:
# [1.423e+01 1.710e+00 2.430e+00 1.560e+01 1.270e+02 2.800e+00 3.060e+00
#  2.800e-01 2.290e+00 5.640e+00 1.040e+00 3.920e+00 1.065e+03]
# [1.423e+01 1.710e+00 2.430e+00 1.560e+01 1.270e+02 2.800e+00 3.060e+00
#  2.800e-01 2.290e+00 5.640e+00 1.040e+00 3.920e+00 1.065e+03 1.000e+00]

# %% [markdown]
# **Submission Requirement**
#
# Please combine your code, plot and results for Q4, Q5 with your answers for Q1, Q2, Q3 together as a single PDF and submit it through Gradescope.
#
# A easy way is, you can save your completed Jupyter notebook as a PDF (e.g. in Chrome, right click the web page -> Print ... -> Save as PDF) and then merge it with your answers for Q1, Q2, Q3.
